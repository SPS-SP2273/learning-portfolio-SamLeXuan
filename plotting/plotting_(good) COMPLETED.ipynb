# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Some nomenclature

# %% [markdown]
# # 2 Comparing the two ‘dialects’

# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()

# %% [markdown]
# ### pyplot Interface

# %%
# Your code here

# %% [markdown]
# ### OO Interface

# %%
# Your code here

# %% [markdown]
# # 3 What is OO ax, really?

# %%
fig, ax = plt.subplots(nrows=2, ncols=1)

ax[0].plot(x, cos_x, label='cos x') # in index 0's plot
ax[1].plot(x, sin_x, label='sin x')

ax[0].legend() # adding a legend for this plot
ax[1].legend()

# %%
fig, ax = plt.subplots(ncols=1, nrows=2) # 1 column 2 row, formatting of subplots

# %%
type(ax) # the format is an array
# Out:
# numpy.ndarray

# %%
ax.shape # 2 'items', column and row
# Out:
# (2,)

# %% [markdown]
# # 4 A complete OO example

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, # 2 rows 1 column
                       figsize=(5, 5),
                       sharex=True) # share the same x axis
ax[0].plot(x, cos_x, label=r'$\cos(x)$')
ax[0].fill_between(x, 0, cos_x, alpha=.25) # fill between x axis and 0, bound by graph
# opacity of .25 indicated by alpha
ax[1].plot(x, sin_x, label=r'$\sin(x)$')
ax[1].fill_between(x, 0, sin_x, alpha=.25)

for a in ax:
    a.legend()
    a.grid(alpha=.25)
    a.set_ylabel('$y$', rotation=0) # rotation rotates y axis label

ax[1].set_xlabel('$x$') # x axis label

fig.suptitle(r'$\sin(x)$ and $\cos(x)$') # main title
fig.tight_layout()

# %% [markdown]
# # 5 Multiple rows and columns

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(5, 5),# figsize is dimension of figure in inches
                       sharex='col', sharey='col')

# Some variables to access the axes and improve readabilty
top_left, top_right, bottom_left, bottom_right = ax.flatten()

top_left.set_title('Top Left') # title for the (position).()
top_right.set_title('Top Right')
bottom_left.set_title('Bottom Left')
bottom_right.set_title('Bottom Right')

top_left.hlines(y=1, xmin=0, xmax=4) # adding reference lines or indicator to plot
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=4)
bottom_right.hlines(y=5, xmin=0, xmax=5)

for a in ax.flatten(): # makes it a 1D array (?)
    a.grid(alpha=.25)

plt.tight_layout()

# %% [markdown]
# ### Using ax

# %%
fig, ax = plt.subplots(nrows=2, ncols=2,
                       figsize=(5, 5),
                       sharex='col', sharey='row')

# %%
ax.shape # array
# Out:
# (2, 2)

# %%
ax[0, 0].set_title('Top Left')
ax[0, 1].set_title('Top Right')
ax[1, 0].set_title('Bottom Left')
ax[1, 1].set_title('Bottom Right')
# Out:
# Text(0.5, 1.0, 'Bottom Right')

# %%
top_left=ax[0, 0]
top_right=ax[0, 1]
bottom_left=ax[1, 0]
bottom_right=ax[1, 1]

#or

top_left, top_right, bottom_left, bottom_right = ax.flatten()

# %%
top_left.hlines(y=1, xmin=0, xmax=5)
top_right.hlines(y=2, xmin=0, xmax=5)
bottom_left.hlines(y=3, xmin=0, xmax=5)
bottom_right.hlines(y=4, xmin=0, xmax=5)

# %% [markdown]
# ## 5.1 Sharing axes

# %%
fig, ax = plt.subplots(
    nrows=2, ncols=2,
    figsize=(5, 5)
)

# %%
fig, ax = plt.subplots(
    nrows=2, ncols=2,
    figsize=(5, 5),
    sharex=True, sharey='row'
)

# %%
fig, ax = plt.subplots(
    nrows=2, ncols=2,
    figsize=(5, 5),
    sharex='col', sharey='row'
)

# %% [markdown]
# ## 5.2 Accessing all axes

# %%
top_left.grid(alpha=.25) # grid opacity
top_right.grid(alpha=.25)
bottom_left.grid(alpha=.25)
bottom_right.grid(alpha=.25)

# %%
for a in ax.flatten():
    a.grid(alpha=.25)

# %% [markdown]
# # 6 Other useful plots

# %% [markdown]
# ## 6.1 Histograms

# %% [markdown]
# ### Data

# %%
# Your code here

# %% [markdown]
# ### A quick helper function

# %%
def get_plot_data():
    data = {}
    filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv'
    data['All'] = np.loadtxt(filename, skiprows=1)

    filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv'
    data['NUS'] = np.loadtxt(filename, skiprows=1)

    return data

# %% [markdown]
# ### The histogram

# %%
def get_plot_data():
    data = {}
    filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_all.csv'
    data['All'] = np.loadtxt(filename, skiprows=1)

    filename = 'sg-gov-graduate-employment-survey_basic_monthly_mean_nus.csv'
    data['NUS'] = np.loadtxt(filename, skiprows=1)

    return data

# %% [markdown]
# ## 6.2 Scatter plots

# %%
plt.style.use("seaborn-v0_8-darkgrid")

data = get_plot_data()

for label, numbers in data.items():
    x = range(len(numbers)) # in range of number of elements in data
    y = numbers
    plt.scatter(x, y, label=label, alpha=.5)

plt.xlabel('Position in the list')
plt.ylabel('Mean of Basic Montly Eraning (S$)')
plt.legend()

# %% [markdown]
# ## 6.3 Bar charts

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys()) 
numbers = list(student_numbers.values())

plt.style.use('ggplot')
plt.bar(majors, numbers) 
plt.xlabel('Majors') 
plt.ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %% [markdown]
# ## 6.4 Pie charts

# %%
student_numbers = {'Life Sciences': 14,
                   'Physics': 12,
                   'Chemistry': 8,
                   'Comp. Biology': 1}
majors = list(student_numbers.keys()) 
numbers = list(student_numbers.values())

plt.style.use('fivethirtyeight')
plt.pie(numbers, 
        labels=majors,
        autopct='%1.1f%%',   # How to format the percentages
        startangle=-90                
        )
plt.title('Percentage of each major')
# Out:
# Text(0.5, 1.0, 'Percentage of each major')
